# %% [markdown]
# # Muon/Track Study
#
# This is a python notebook to help you get started analyzing simulated muon collider data.
#
# This notebook focus on the muon gun sample, which simulates a single muon per event in the detector.
#
# We'll compare those 'truth' muons to reconstructed inner detector tracks and muon particle flow candidates

# %%
# Import relevant packages

import uproot # conda install -c conda-forge uproot
import vector # conda install -c conda-forge vector
import awkward as ak
import numpy as np
import matplotlib.pyplot as plt
import math
plt.style.use('seaborn-v0_8-colorblind')

# %% [markdown]
# ## Inspect the file contents
#
# * Open a single root file with uproot
# * Access the tree 'events'
# * And print out the list of branches in the tree

# %%
# open a single file for testing

f = uproot.open("../inputs/muonGun/edm4hepBIB/muonGun_reco_10.root")

# %%
tree = f["events"]

# %%
# Get the list of branches in the tree
for branch in tree.keys():
    print(branch)
# Out:
# TightSelectedPandoraPFOs#0
# TightSelectedPandoraPFOs#0/TightSelectedPandoraPFOs#0.index
# TightSelectedPandoraPFOs#0/TightSelectedPandoraPFOs#0.collectionID
# SiTracks#0
# SiTracks#0/SiTracks#0.index
# SiTracks#0/SiTracks#0.collectionID
# SelectedPandoraPFOs#0
# SelectedPandoraPFOs#0/SelectedPandoraPFOs#0.index
# SelectedPandoraPFOs#0/SelectedPandoraPFOs#0.collectionID
# LooseSelectedPandoraPFOs#0
# LooseSelectedPandoraPFOs#0/LooseSelectedPandoraPFOs#0.index
# LooseSelectedPandoraPFOs#0/LooseSelectedPandoraPFOs#0.collectionID
# LE_SelectedPandoraPFOs#0
# LE_SelectedPandoraPFOs#0/LE_SelectedPandoraPFOs#0.index
# LE_SelectedPandoraPFOs#0/LE_SelectedPandoraPFOs#0.collectionID
# LE_LooseSelectedPandoraPFOs#0
# LE_LooseSelectedPandoraPFOs#0/LE_LooseSelectedPandoraPFOs#0.index
# LE_LooseSelectedPandoraPFOs#0/LE_LooseSelectedPandoraPFOs#0.collectionID
# MCPhysicsParticles#0
# MCPhysicsParticles#0/MCPhysicsParticles#0.index
# MCPhysicsParticles#0/MCPhysicsParticles#0.collectionID
# YokeEndcapCollection
# YokeEndcapCollection/YokeEndcapCollection.cellID
# YokeEndcapCollection/YokeEndcapCollection.energy
# YokeEndcapCollection/YokeEndcapCollection.position.x
# YokeEndcapCollection/YokeEndcapCollection.position.y
# YokeEndcapCollection/YokeEndcapCollection.position.z
# YokeEndcapCollection/YokeEndcapCollection.contributions_begin
# YokeEndcapCollection/YokeEndcapCollection.contributions_end
# YokeEndcapCollection#0
# YokeEndcapCollection#0/YokeEndcapCollection#0.index
# YokeEndcapCollection#0/YokeEndcapCollection#0.collectionID
# IBTrackerHits
# IBTrackerHits/IBTrackerHits.cellID
# IBTrackerHits/IBTrackerHits.type
# IBTrackerHits/IBTrackerHits.quality
# IBTrackerHits/IBTrackerHits.time
# IBTrackerHits/IBTrackerHits.eDep
# IBTrackerHits/IBTrackerHits.eDepError
# IBTrackerHits/IBTrackerHits.u.a
# IBTrackerHits/IBTrackerHits.u.b
# IBTrackerHits/IBTrackerHits.v.a
# IBTrackerHits/IBTrackerHits.v.b
# IBTrackerHits/IBTrackerHits.du
# IBTrackerHits/IBTrackerHits.dv
# IBTrackerHits/IBTrackerHits.position.x
# IBTrackerHits/IBTrackerHits.position.y
# IBTrackerHits/IBTrackerHits.position.z
# IBTrackerHits/IBTrackerHits.covMatrix[6]
# IBTrackerHits/IBTrackerHits.rawHits_begin
# IBTrackerHits/IBTrackerHits.rawHits_end
# IBTrackerHits_0
# IBTrackerHits_0/IBTrackerHits_0.index
# IBTrackerHits_0/IBTrackerHits_0.collectionID
# CaloHitContribution
# CaloHitContribution/CaloHitContribution.PDG
# CaloHitContribution/CaloHitContribution.energy
# CaloHitContribution/CaloHitContribution.time
# CaloHitContribution/CaloHitContribution.stepPosition.x
# CaloHitContribution/CaloHitContribution.stepPosition.y
# CaloHitContribution/CaloHitContribution.stepPosition.z
# CaloHitContribution#0
# CaloHitContribution#0/CaloHitContribution#0.index
# CaloHitContribution#0/CaloHitContribution#0.collectionID
# PandoraClusters
# PandoraClusters/PandoraClusters.type
# PandoraClusters/PandoraClusters.energy
# PandoraClusters/PandoraClusters.energyError
# PandoraClusters/PandoraClusters.position.x
# PandoraClusters/PandoraClusters.position.y
# PandoraClusters/PandoraClusters.position.z
# PandoraClusters/PandoraClusters.positionError[6]
# PandoraClusters/PandoraClusters.iTheta
# PandoraClusters/PandoraClusters.phi
# PandoraClusters/PandoraClusters.directionError.x
# PandoraClusters/PandoraClusters.directionError.y
# PandoraClusters/PandoraClusters.directionError.z
# PandoraClusters/PandoraClusters.shapeParameters_begin
# PandoraClusters/PandoraClusters.shapeParameters_end
# PandoraClusters/PandoraClusters.subdetectorEnergies_begin
# PandoraClusters/PandoraClusters.subdetectorEnergies_end
# PandoraClusters/PandoraClusters.clusters_begin
# PandoraClusters/PandoraClusters.clusters_end
# PandoraClusters/PandoraClusters.hits_begin
# PandoraClusters/PandoraClusters.hits_end
# PandoraClusters/PandoraClusters.particleIDs_begin
# PandoraClusters/PandoraClusters.particleIDs_end
# PandoraClusters#0
# PandoraClusters#0/PandoraClusters#0.index
# PandoraClusters#0/PandoraClusters#0.collectionID
# PandoraClusters#1
# PandoraClusters#1/PandoraClusters#1.index
# PandoraClusters#1/PandoraClusters#1.collectionID
# PandoraClusters#2
# PandoraClusters#2/PandoraClusters#2.index
# PandoraClusters#2/PandoraClusters#2.collectionID
# PandoraClusters_0
# PandoraClusters_1
# PandoraPFOs_particleIDs
# PandoraPFOs_particleIDs/PandoraPFOs_particleIDs.type
# PandoraPFOs_particleIDs/PandoraPFOs_particleIDs.PDG
# PandoraPFOs_particleIDs/PandoraPFOs_particleIDs.algorithmType
# PandoraPFOs_particleIDs/PandoraPFOs_particleIDs.likelihood
# PandoraPFOs_particleIDs/PandoraPFOs_particleIDs.parameters_begin
# PandoraPFOs_particleIDs/PandoraPFOs_particleIDs.parameters_end
# PandoraPFOs_particleIDs_0
# HCalBarrelCollection
# HCalBarrelCollection/HCalBarrelCollection.cellID
# HCalBarrelCollection/HCalBarrelCollection.energy
# HCalBarrelCollection/HCalBarrelCollection.position.x
# HCalBarrelCollection/HCalBarrelCollection.position.y
# HCalBarrelCollection/HCalBarrelCollection.position.z
# HCalBarrelCollection/HCalBarrelCollection.contributions_begin
# HCalBarrelCollection/HCalBarrelCollection.contributions_end
# HCalBarrelCollection#0
# HCalBarrelCollection#0/HCalBarrelCollection#0.index
# HCalBarrelCollection#0/HCalBarrelCollection#0.collectionID
# ECalEndcapCollection
# ECalEndcapCollection/ECalEndcapCollection.cellID
# ECalEndcapCollection/ECalEndcapCollection.energy
# ECalEndcapCollection/ECalEndcapCollection.position.x
# ECalEndcapCollection/ECalEndcapCollection.position.y
# ECalEndcapCollection/ECalEndcapCollection.position.z
# ECalEndcapCollection/ECalEndcapCollection.contributions_begin
# ECalEndcapCollection/ECalEndcapCollection.contributions_end
# ECalEndcapCollection#0
# ECalEndcapCollection#0/ECalEndcapCollection#0.index
# ECalEndcapCollection#0/ECalEndcapCollection#0.collectionID
# PandoraPFOs
# PandoraPFOs/PandoraPFOs.type
# PandoraPFOs/PandoraPFOs.energy
# PandoraPFOs/PandoraPFOs.momentum.x
# PandoraPFOs/PandoraPFOs.momentum.y
# PandoraPFOs/PandoraPFOs.momentum.z
# PandoraPFOs/PandoraPFOs.referencePoint.x
# PandoraPFOs/PandoraPFOs.referencePoint.y
# PandoraPFOs/PandoraPFOs.referencePoint.z
# PandoraPFOs/PandoraPFOs.charge
# PandoraPFOs/PandoraPFOs.mass
# PandoraPFOs/PandoraPFOs.goodnessOfPID
# PandoraPFOs/PandoraPFOs.covMatrix[10]
# PandoraPFOs/PandoraPFOs.clusters_begin
# PandoraPFOs/PandoraPFOs.clusters_end
# PandoraPFOs/PandoraPFOs.tracks_begin
# PandoraPFOs/PandoraPFOs.tracks_end
# PandoraPFOs/PandoraPFOs.particles_begin
# PandoraPFOs/PandoraPFOs.particles_end
# PandoraPFOs/PandoraPFOs.particleIDs_begin
# PandoraPFOs/PandoraPFOs.particleIDs_end
# PandoraPFOs#0
# PandoraPFOs#0/PandoraPFOs#0.index
# PandoraPFOs#0/PandoraPFOs#0.collectionID
# PandoraPFOs#1
# PandoraPFOs#1/PandoraPFOs#1.index
# PandoraPFOs#1/PandoraPFOs#1.collectionID
# PandoraPFOs#2
# PandoraPFOs#2/PandoraPFOs#2.index
# PandoraPFOs#2/PandoraPFOs#2.collectionID
# PandoraPFOs#3
# PandoraPFOs#3/PandoraPFOs#3.index
# PandoraPFOs#3/PandoraPFOs#3.collectionID
# PandoraPFOs#4
# PandoraPFOs#4/PandoraPFOs#4.index
# PandoraPFOs#4/PandoraPFOs#4.collectionID
# PandoraPFOs#5
# PandoraPFOs#5/PandoraPFOs#5.index
# PandoraPFOs#5/PandoraPFOs#5.collectionID
# HCALEndcap
# HCALEndcap/HCALEndcap.cellID
# HCALEndcap/HCALEndcap.energy
# HCALEndcap/HCALEndcap.energyError
# HCALEndcap/HCALEndcap.time
# HCALEndcap/HCALEndcap.position.x
# HCALEndcap/HCALEndcap.position.y
# HCALEndcap/HCALEndcap.position.z
# HCALEndcap/HCALEndcap.type
# HCALBarrel
# HCALBarrel/HCALBarrel.cellID
# HCALBarrel/HCALBarrel.energy
# HCALBarrel/HCALBarrel.energyError
# HCALBarrel/HCALBarrel.time
# HCALBarrel/HCALBarrel.position.x
# HCALBarrel/HCALBarrel.position.y
# HCALBarrel/HCALBarrel.position.z
# HCALBarrel/HCALBarrel.type
# YokeBarrelCollection
# YokeBarrelCollection/YokeBarrelCollection.cellID
# YokeBarrelCollection/YokeBarrelCollection.energy
# YokeBarrelCollection/YokeBarrelCollection.position.x
# YokeBarrelCollection/YokeBarrelCollection.position.y
# YokeBarrelCollection/YokeBarrelCollection.position.z
# YokeBarrelCollection/YokeBarrelCollection.contributions_begin
# YokeBarrelCollection/YokeBarrelCollection.contributions_end
# YokeBarrelCollection#0
# YokeBarrelCollection#0/YokeBarrelCollection#0.index
# YokeBarrelCollection#0/YokeBarrelCollection#0.collectionID
# ECalBarrelCollection
# ECalBarrelCollection/ECalBarrelCollection.cellID
# ECalBarrelCollection/ECalBarrelCollection.energy
# ECalBarrelCollection/ECalBarrelCollection.position.x
# ECalBarrelCollection/ECalBarrelCollection.position.y
# ECalBarrelCollection/ECalBarrelCollection.position.z
# ECalBarrelCollection/ECalBarrelCollection.contributions_begin
# ECalBarrelCollection/ECalBarrelCollection.contributions_end
# ECalBarrelCollection#0
# ECalBarrelCollection#0/ECalBarrelCollection#0.index
# ECalBarrelCollection#0/ECalBarrelCollection#0.collectionID
# PandoraStartVertices
# PandoraStartVertices/PandoraStartVertices.primary
# PandoraStartVertices/PandoraStartVertices.chi2
# PandoraStartVertices/PandoraStartVertices.probability
# PandoraStartVertices/PandoraStartVertices.position.x
# PandoraStartVertices/PandoraStartVertices.position.y
# PandoraStartVertices/PandoraStartVertices.position.z
# PandoraStartVertices/PandoraStartVertices.covMatrix[6]
# PandoraStartVertices/PandoraStartVertices.algorithmType
# PandoraStartVertices/PandoraStartVertices.parameters_begin
# PandoraStartVertices/PandoraStartVertices.parameters_end
# PandoraStartVertices#0
# PandoraStartVertices#0/PandoraStartVertices#0.index
# PandoraStartVertices#0/PandoraStartVertices#0.collectionID
# PandoraStartVertices_0
# HCalEndcapCollection
# HCalEndcapCollection/HCalEndcapCollection.cellID
# HCalEndcapCollection/HCalEndcapCollection.energy
# HCalEndcapCollection/HCalEndcapCollection.position.x
# HCalEndcapCollection/HCalEndcapCollection.position.y
# HCalEndcapCollection/HCalEndcapCollection.position.z
# HCalEndcapCollection/HCalEndcapCollection.contributions_begin
# HCalEndcapCollection/HCalEndcapCollection.contributions_end
# HCalEndcapCollection#0
# HCalEndcapCollection#0/HCalEndcapCollection#0.index
# HCalEndcapCollection#0/HCalEndcapCollection#0.collectionID
# HCALOther
# HCALOther/HCALOther.cellID
# HCALOther/HCALOther.energy
# HCALOther/HCALOther.energyError
# HCALOther/HCALOther.time
# HCALOther/HCALOther.position.x
# HCALOther/HCALOther.position.y
# HCALOther/HCALOther.position.z
# HCALOther/HCALOther.type
# VETrackerHits
# VETrackerHits/VETrackerHits.cellID
# VETrackerHits/VETrackerHits.type
# VETrackerHits/VETrackerHits.quality
# VETrackerHits/VETrackerHits.time
# VETrackerHits/VETrackerHits.eDep
# VETrackerHits/VETrackerHits.eDepError
# VETrackerHits/VETrackerHits.u.a
# VETrackerHits/VETrackerHits.u.b
# VETrackerHits/VETrackerHits.v.a
# VETrackerHits/VETrackerHits.v.b
# VETrackerHits/VETrackerHits.du
# VETrackerHits/VETrackerHits.dv
# VETrackerHits/VETrackerHits.position.x
# VETrackerHits/VETrackerHits.position.y
# VETrackerHits/VETrackerHits.position.z
# VETrackerHits/VETrackerHits.covMatrix[6]
# VETrackerHits/VETrackerHits.rawHits_begin
# VETrackerHits/VETrackerHits.rawHits_end
# VETrackerHits_0
# VETrackerHits_0/VETrackerHits_0.index
# VETrackerHits_0/VETrackerHits_0.collectionID
# OBTrackerHits
# OBTrackerHits/OBTrackerHits.cellID
# OBTrackerHits/OBTrackerHits.type
# OBTrackerHits/OBTrackerHits.quality
# OBTrackerHits/OBTrackerHits.time
# OBTrackerHits/OBTrackerHits.eDep
# OBTrackerHits/OBTrackerHits.eDepError
# OBTrackerHits/OBTrackerHits.u.a
# OBTrackerHits/OBTrackerHits.u.b
# OBTrackerHits/OBTrackerHits.v.a
# OBTrackerHits/OBTrackerHits.v.b
# OBTrackerHits/OBTrackerHits.du
# OBTrackerHits/OBTrackerHits.dv
# OBTrackerHits/OBTrackerHits.position.x
# OBTrackerHits/OBTrackerHits.position.y
# OBTrackerHits/OBTrackerHits.position.z
# OBTrackerHits/OBTrackerHits.covMatrix[6]
# OBTrackerHits/OBTrackerHits.rawHits_begin
# OBTrackerHits/OBTrackerHits.rawHits_end
# OBTrackerHits_0
# OBTrackerHits_0/OBTrackerHits_0.index
# OBTrackerHits_0/OBTrackerHits_0.collectionID
# ECALEndcap
# ECALEndcap/ECALEndcap.cellID
# ECALEndcap/ECALEndcap.energy
# ECALEndcap/ECALEndcap.energyError
# ECALEndcap/ECALEndcap.time
# ECALEndcap/ECALEndcap.position.x
# ECALEndcap/ECALEndcap.position.y
# ECALEndcap/ECALEndcap.position.z
# ECALEndcap/ECALEndcap.type
# HCalRingCollection
# HCalRingCollection/HCalRingCollection.cellID
# HCalRingCollection/HCalRingCollection.energy
# HCalRingCollection/HCalRingCollection.position.x
# HCalRingCollection/HCalRingCollection.position.y
# HCalRingCollection/HCalRingCollection.position.z
# HCalRingCollection/HCalRingCollection.contributions_begin
# HCalRingCollection/HCalRingCollection.contributions_end
# HCalRingCollection#0
# HCalRingCollection#0/HCalRingCollection#0.index
# HCalRingCollection#0/HCalRingCollection#0.collectionID
# JetOut_particleIDs
# JetOut_particleIDs/JetOut_particleIDs.type
# JetOut_particleIDs/JetOut_particleIDs.PDG
# JetOut_particleIDs/JetOut_particleIDs.algorithmType
# JetOut_particleIDs/JetOut_particleIDs.likelihood
# JetOut_particleIDs/JetOut_particleIDs.parameters_begin
# JetOut_particleIDs/JetOut_particleIDs.parameters_end
# JetOut_particleIDs_0
# AllTracks
# AllTracks/AllTracks.type
# AllTracks/AllTracks.chi2
# AllTracks/AllTracks.ndf
# AllTracks/AllTracks.dEdx
# AllTracks/AllTracks.dEdxError
# AllTracks/AllTracks.radiusOfInnermostHit
# AllTracks/AllTracks.subDetectorHitNumbers_begin
# AllTracks/AllTracks.subDetectorHitNumbers_end
# AllTracks/AllTracks.trackStates_begin
# AllTracks/AllTracks.trackStates_end
# AllTracks/AllTracks.dxQuantities_begin
# AllTracks/AllTracks.dxQuantities_end
# AllTracks/AllTracks.trackerHits_begin
# AllTracks/AllTracks.trackerHits_end
# AllTracks/AllTracks.tracks_begin
# AllTracks/AllTracks.tracks_end
# AllTracks#0
# AllTracks#0/AllTracks#0.index
# AllTracks#0/AllTracks#0.collectionID
# AllTracks#1
# AllTracks#1/AllTracks#1.index
# AllTracks#1/AllTracks#1.collectionID
# AllTracks_0
# AllTracks_1
# AllTracks_1/AllTracks_1.location
# AllTracks_1/AllTracks_1.D0
# AllTracks_1/AllTracks_1.phi
# AllTracks_1/AllTracks_1.omega
# AllTracks_1/AllTracks_1.Z0
# AllTracks_1/AllTracks_1.tanLambda
# AllTracks_1/AllTracks_1.time
# AllTracks_1/AllTracks_1.referencePoint.x
# AllTracks_1/AllTracks_1.referencePoint.y
# AllTracks_1/AllTracks_1.referencePoint.z
# AllTracks_1/AllTracks_1.covMatrix[21]
# AllTracks_2
# AllTracks_2/AllTracks_2.type
# AllTracks_2/AllTracks_2.value
# AllTracks_2/AllTracks_2.error
# IETrackerHits
# IETrackerHits/IETrackerHits.cellID
# IETrackerHits/IETrackerHits.type
# IETrackerHits/IETrackerHits.quality
# IETrackerHits/IETrackerHits.time
# IETrackerHits/IETrackerHits.eDep
# IETrackerHits/IETrackerHits.eDepError
# IETrackerHits/IETrackerHits.u.a
# IETrackerHits/IETrackerHits.u.b
# IETrackerHits/IETrackerHits.v.a
# IETrackerHits/IETrackerHits.v.b
# IETrackerHits/IETrackerHits.du
# IETrackerHits/IETrackerHits.dv
# IETrackerHits/IETrackerHits.position.x
# IETrackerHits/IETrackerHits.position.y
# IETrackerHits/IETrackerHits.position.z
# IETrackerHits/IETrackerHits.covMatrix[6]
# IETrackerHits/IETrackerHits.rawHits_begin
# IETrackerHits/IETrackerHits.rawHits_end
# IETrackerHits_0
# IETrackerHits_0/IETrackerHits_0.index
# IETrackerHits_0/IETrackerHits_0.collectionID
# ECALBarrel
# ECALBarrel/ECALBarrel.cellID
# ECALBarrel/ECALBarrel.energy
# ECALBarrel/ECALBarrel.energyError
# ECALBarrel/ECALBarrel.time
# ECALBarrel/ECALBarrel.position.x
# ECALBarrel/ECALBarrel.position.y
# ECALBarrel/ECALBarrel.position.z
# ECALBarrel/ECALBarrel.type
# JetOut
# JetOut/JetOut.type
# JetOut/JetOut.energy
# JetOut/JetOut.momentum.x
# JetOut/JetOut.momentum.y
# JetOut/JetOut.momentum.z
# JetOut/JetOut.referencePoint.x
# JetOut/JetOut.referencePoint.y
# JetOut/JetOut.referencePoint.z
# JetOut/JetOut.charge
# JetOut/JetOut.mass
# JetOut/JetOut.goodnessOfPID
# JetOut/JetOut.covMatrix[10]
# JetOut/JetOut.clusters_begin
# JetOut/JetOut.clusters_end
# JetOut/JetOut.tracks_begin
# JetOut/JetOut.tracks_end
# JetOut/JetOut.particles_begin
# JetOut/JetOut.particles_end
# JetOut/JetOut.particleIDs_begin
# JetOut/JetOut.particleIDs_end
# JetOut#0
# JetOut#0/JetOut#0.index
# JetOut#0/JetOut#0.collectionID
# JetOut#1
# JetOut#1/JetOut#1.index
# JetOut#1/JetOut#1.collectionID
# JetOut#2
# JetOut#2/JetOut#2.index
# JetOut#2/JetOut#2.collectionID
# JetOut#3
# JetOut#3/JetOut#3.index
# JetOut#3/JetOut#3.collectionID
# JetOut#4
# JetOut#4/JetOut#4.index
# JetOut#4/JetOut#4.collectionID
# JetOut#5
# JetOut#5/JetOut#5.index
# JetOut#5/JetOut#5.collectionID
# MCParticle
# MCParticle/MCParticle.PDG
# MCParticle/MCParticle.generatorStatus
# MCParticle/MCParticle.simulatorStatus
# MCParticle/MCParticle.charge
# MCParticle/MCParticle.time
# MCParticle/MCParticle.mass
# MCParticle/MCParticle.vertex.x
# MCParticle/MCParticle.vertex.y
# MCParticle/MCParticle.vertex.z
# MCParticle/MCParticle.endpoint.x
# MCParticle/MCParticle.endpoint.y
# MCParticle/MCParticle.endpoint.z
# MCParticle/MCParticle.momentum.x
# MCParticle/MCParticle.momentum.y
# MCParticle/MCParticle.momentum.z
# MCParticle/MCParticle.momentumAtEndpoint.x
# MCParticle/MCParticle.momentumAtEndpoint.y
# MCParticle/MCParticle.momentumAtEndpoint.z
# MCParticle/MCParticle.spin.x
# MCParticle/MCParticle.spin.y
# MCParticle/MCParticle.spin.z
# MCParticle/MCParticle.colorFlow.a
# MCParticle/MCParticle.colorFlow.b
# MCParticle/MCParticle.parents_begin
# MCParticle/MCParticle.parents_end
# MCParticle/MCParticle.daughters_begin
# MCParticle/MCParticle.daughters_end
# MCParticle#0
# MCParticle#0/MCParticle#0.index
# MCParticle#0/MCParticle#0.collectionID
# MCParticle#1
# MCParticle#1/MCParticle#1.index
# MCParticle#1/MCParticle#1.collectionID
# MUON
# MUON/MUON.cellID
# MUON/MUON.energy
# MUON/MUON.energyError
# MUON/MUON.time
# MUON/MUON.position.x
# MUON/MUON.position.y
# MUON/MUON.position.z
# MUON/MUON.type
# OETrackerHits
# OETrackerHits/OETrackerHits.cellID
# OETrackerHits/OETrackerHits.type
# OETrackerHits/OETrackerHits.quality
# OETrackerHits/OETrackerHits.time
# OETrackerHits/OETrackerHits.eDep
# OETrackerHits/OETrackerHits.eDepError
# OETrackerHits/OETrackerHits.u.a
# OETrackerHits/OETrackerHits.u.b
# OETrackerHits/OETrackerHits.v.a
# OETrackerHits/OETrackerHits.v.b
# OETrackerHits/OETrackerHits.du
# OETrackerHits/OETrackerHits.dv
# OETrackerHits/OETrackerHits.position.x
# OETrackerHits/OETrackerHits.position.y
# OETrackerHits/OETrackerHits.position.z
# OETrackerHits/OETrackerHits.covMatrix[6]
# OETrackerHits/OETrackerHits.rawHits_begin
# OETrackerHits/OETrackerHits.rawHits_end
# OETrackerHits_0
# OETrackerHits_0/OETrackerHits_0.index
# OETrackerHits_0/OETrackerHits_0.collectionID
# LE_TightSelectedPandoraPFOs#0
# LE_TightSelectedPandoraPFOs#0/LE_TightSelectedPandoraPFOs#0.index
# LE_TightSelectedPandoraPFOs#0/LE_TightSelectedPandoraPFOs#0.collectionID
# SeedTracks
# SeedTracks/SeedTracks.type
# SeedTracks/SeedTracks.chi2
# SeedTracks/SeedTracks.ndf
# SeedTracks/SeedTracks.dEdx
# SeedTracks/SeedTracks.dEdxError
# SeedTracks/SeedTracks.radiusOfInnermostHit
# SeedTracks/SeedTracks.subDetectorHitNumbers_begin
# SeedTracks/SeedTracks.subDetectorHitNumbers_end
# SeedTracks/SeedTracks.trackStates_begin
# SeedTracks/SeedTracks.trackStates_end
# SeedTracks/SeedTracks.dxQuantities_begin
# SeedTracks/SeedTracks.dxQuantities_end
# SeedTracks/SeedTracks.trackerHits_begin
# SeedTracks/SeedTracks.trackerHits_end
# SeedTracks/SeedTracks.tracks_begin
# SeedTracks/SeedTracks.tracks_end
# SeedTracks#0
# SeedTracks#0/SeedTracks#0.index
# SeedTracks#0/SeedTracks#0.collectionID
# SeedTracks#1
# SeedTracks#1/SeedTracks#1.index
# SeedTracks#1/SeedTracks#1.collectionID
# SeedTracks_0
# SeedTracks_1
# SeedTracks_1/SeedTracks_1.location
# SeedTracks_1/SeedTracks_1.D0
# SeedTracks_1/SeedTracks_1.phi
# SeedTracks_1/SeedTracks_1.omega
# SeedTracks_1/SeedTracks_1.Z0
# SeedTracks_1/SeedTracks_1.tanLambda
# SeedTracks_1/SeedTracks_1.time
# SeedTracks_1/SeedTracks_1.referencePoint.x
# SeedTracks_1/SeedTracks_1.referencePoint.y
# SeedTracks_1/SeedTracks_1.referencePoint.z
# SeedTracks_1/SeedTracks_1.covMatrix[21]
# SeedTracks_2
# SeedTracks_2/SeedTracks_2.type
# SeedTracks_2/SeedTracks_2.value
# SeedTracks_2/SeedTracks_2.error
# SiTracks_Refitted
# SiTracks_Refitted/SiTracks_Refitted.type
# SiTracks_Refitted/SiTracks_Refitted.chi2
# SiTracks_Refitted/SiTracks_Refitted.ndf
# SiTracks_Refitted/SiTracks_Refitted.dEdx
# SiTracks_Refitted/SiTracks_Refitted.dEdxError
# SiTracks_Refitted/SiTracks_Refitted.radiusOfInnermostHit
# SiTracks_Refitted/SiTracks_Refitted.subDetectorHitNumbers_begin
# SiTracks_Refitted/SiTracks_Refitted.subDetectorHitNumbers_end
# SiTracks_Refitted/SiTracks_Refitted.trackStates_begin
# SiTracks_Refitted/SiTracks_Refitted.trackStates_end
# SiTracks_Refitted/SiTracks_Refitted.dxQuantities_begin
# SiTracks_Refitted/SiTracks_Refitted.dxQuantities_end
# SiTracks_Refitted/SiTracks_Refitted.trackerHits_begin
# SiTracks_Refitted/SiTracks_Refitted.trackerHits_end
# SiTracks_Refitted/SiTracks_Refitted.tracks_begin
# SiTracks_Refitted/SiTracks_Refitted.tracks_end
# SiTracks_Refitted#0
# SiTracks_Refitted#0/SiTracks_Refitted#0.index
# SiTracks_Refitted#0/SiTracks_Refitted#0.collectionID
# SiTracks_Refitted#1
# SiTracks_Refitted#1/SiTracks_Refitted#1.index
# SiTracks_Refitted#1/SiTracks_Refitted#1.collectionID
# SiTracks_Refitted_0
# SiTracks_Refitted_1
# SiTracks_Refitted_1/SiTracks_Refitted_1.location
# SiTracks_Refitted_1/SiTracks_Refitted_1.D0
# SiTracks_Refitted_1/SiTracks_Refitted_1.phi
# SiTracks_Refitted_1/SiTracks_Refitted_1.omega
# SiTracks_Refitted_1/SiTracks_Refitted_1.Z0
# SiTracks_Refitted_1/SiTracks_Refitted_1.tanLambda
# SiTracks_Refitted_1/SiTracks_Refitted_1.time
# SiTracks_Refitted_1/SiTracks_Refitted_1.referencePoint.x
# SiTracks_Refitted_1/SiTracks_Refitted_1.referencePoint.y
# SiTracks_Refitted_1/SiTracks_Refitted_1.referencePoint.z
# SiTracks_Refitted_1/SiTracks_Refitted_1.covMatrix[21]
# SiTracks_Refitted_2
# SiTracks_Refitted_2/SiTracks_Refitted_2.type
# SiTracks_Refitted_2/SiTracks_Refitted_2.value
# SiTracks_Refitted_2/SiTracks_Refitted_2.error
# VBTrackerHits
# VBTrackerHits/VBTrackerHits.cellID
# VBTrackerHits/VBTrackerHits.type
# VBTrackerHits/VBTrackerHits.quality
# VBTrackerHits/VBTrackerHits.time
# VBTrackerHits/VBTrackerHits.eDep
# VBTrackerHits/VBTrackerHits.eDepError
# VBTrackerHits/VBTrackerHits.u.a
# VBTrackerHits/VBTrackerHits.u.b
# VBTrackerHits/VBTrackerHits.v.a
# VBTrackerHits/VBTrackerHits.v.b
# VBTrackerHits/VBTrackerHits.du
# VBTrackerHits/VBTrackerHits.dv
# VBTrackerHits/VBTrackerHits.position.x
# VBTrackerHits/VBTrackerHits.position.y
# VBTrackerHits/VBTrackerHits.position.z
# VBTrackerHits/VBTrackerHits.covMatrix[6]
# VBTrackerHits/VBTrackerHits.rawHits_begin
# VBTrackerHits/VBTrackerHits.rawHits_end
# VBTrackerHits_0
# VBTrackerHits_0/VBTrackerHits_0.index
# VBTrackerHits_0/VBTrackerHits_0.collectionID
# PARAMETERS
# PARAMETERS/_intMap
# PARAMETERS/_intMap/_intMap.first
# PARAMETERS/_intMap/_intMap.second
# PARAMETERS/_floatMap
# PARAMETERS/_floatMap/_floatMap.first
# PARAMETERS/_floatMap/_floatMap.second
# PARAMETERS/_stringMap
# PARAMETERS/_stringMap/_stringMap.first
# PARAMETERS/_stringMap/_stringMap.second
# PARAMETERS/_doubleMap
# PARAMETERS/_doubleMap/_doubleMap.first
# PARAMETERS/_doubleMap/_doubleMap.second

# %% [markdown]
# ##  Convenient ways to access information from multiple files
#
# 1. Read in multiple files at once with
# ```
# uproot.concatenate # to process all files at once
# uproot.iterate # to process in batches
# ```
# 2. Zip up useful information about truth particles ```MCParticle```, muon spectrometer hits ```MUON```, and silicon tracks ```SiTracks_Refitted``` into position/momentum vectors.
#
# ```
# vector.register_awkward()
# particles = ak.zip({"px": ..., "py": ...}, with_name="Momentum4D")
# ```
#
# See https://github.com/scikit-hep/vector to learn about possible types of & what information you need to form vectors
#
# See https://github.com/key4hep/EDM4hep/blob/master/edm4hep.yaml for more info about edm4hep format

# %%
#
# open multiple files at once, only save relevant information
#
tree = uproot.concatenate("../inputs/muonGun/edm4hepBIB/muonGun_reco_*.root:events",filter_name=["MC*","MUON*","SiTracks*"])

# %% [markdown]
# ## Read in Monte Carlo truth particles
#
#
# Learn pdgID naming conventions here:
# https://pdg.lbl.gov/2007/reviews/montecarlorpp.pdf
#
# Learn more about MC data format, including generator status codes here
# https://arxiv.org/pdf/1912.08005.pdf

# %%
# read in truth particles from Monte Carlo
vector.register_awkward()
mcPart = ak.zip({"px": tree["MCParticle.momentum.x"], 
                 "py": tree["MCParticle.momentum.y"], 
                 "pz": tree["MCParticle.momentum.z"], 
                 "mass": tree["MCParticle.mass"], 
                 "pdg": tree["MCParticle.PDG"],
                 "status": tree["MCParticle.generatorStatus"],
                 "vtxX" : tree["MCParticle.vertex.x"],
                 "vtxY" : tree["MCParticle.vertex.y"],
                 "vtxZ" : tree["MCParticle.vertex.z"],
                 "endX" : tree["MCParticle.endpoint.x"],
                 "endY" : tree["MCParticle.endpoint.y"],
                 "endZ" : tree["MCParticle.endpoint.z"],
                 "charge": tree["MCParticle.charge"],
                 "time" : tree["MCParticle.time"]},
                                   with_name="Momentum4D")


# select only status 1 particles, with muon PDG ID
truthMuons = mcPart[ (mcPart.status==1) & (abs(mcPart.pdg)==13)]

# %% [markdown]
# ## Test different ways to access information
#
# * printout an entire array at once
# * loop over one event at a time, and one particle at a time

# %%
# printout the awkward array itself
print(truthMuons.pt)
print("")

# printout info per event
for i in range(0,10):
    
    print("event ",i)
    
    for muon in truthMuons[i]:
        print("  pt {:.1f}, eta {:.1f}, phi {:.1f}".format(muon.pt, muon.eta, muon.phi))
        
    if i > 3: break
# Out:
# [[87.7], [141], [10.1], [610], [366], ..., [128], [218], [180], [322], [1.02]]
#
# event  0
#   pt 87.7, eta 0.6, phi -1.6
# event  1
#   pt 140.9, eta -2.3, phi 1.1
# event  2
#   pt 10.1, eta 1.0, phi 0.6
# event  3
#   pt 609.6, eta -0.4, phi 2.6
# event  4
#   pt 366.2, eta -0.2, phi -2.7

# %% [markdown]
# ## Read in Muon System Hits

# %%
# read in Muon System Hits
muonHits = ak.zip({"x" : tree["MUON.position.x"], 
                "y" : tree["MUON.position.y"], 
                "z" : tree["MUON.position.z"], 
                "E" : tree["MUON.energy"], 
                "Eerr" : tree["MUON.energyError"], 
                "t": tree["MUON.energy"], 
                "type": tree["MUON.type"] },
                                   with_name="VectorObject4D")

# %% [markdown]
# ## Read in Inner Detector Tracks
#
# We're interested in ```SiTracks_Refitted```.
#
# Note that ```SiTracks_Refitted_1``` saves track parameter measurements at four different locations. We're only  interested in location==1
# *    AtOther = 0  # any location other than the ones defined below
# *    AtIP = 1
# *    AtFirstHit = 2
# *    AtLastHit = 3
# *    AtCalorimeter = 4
# *    AtVertex = 5
# *    LastLocation = AtVertex

# %%
# Some useful code for converting from measured track parameters to pt/theta
# adapted from https://github.com/madbaron/LCIOmacros/blob/master/study_tracks.py

Bfield = 3.56  # T

def pt(omega):
    pt = 0.3 * Bfield / abs(omega * 1000.)
    return pt

def theta(tanLambda):
    theta = math.pi/2- np.arctan(tanLambda)
    return theta

# %%
# read in Inner Detector tracks

atIP = tree["SiTracks_Refitted_1.location"]==1 # select only measurements at IP

track_mass = 0.135*ak.ones_like(tree["SiTracks_Refitted.type"]) # make a mass array to initialize lorentz vector

# read in silicon tracks.... not sure if this is the collection we want, probably all tracks
tracks = ak.zip({"pt"    : pt(tree["SiTracks_Refitted_1.omega"][atIP]) ,
                 "theta" : theta(tree["SiTracks_Refitted_1.tanLambda"][atIP]) ,
                 "phi"   : tree["SiTracks_Refitted_1.phi"][atIP] ,
                 "mass"  : track_mass,
                 "d0"    : tree["SiTracks_Refitted_1.D0"][atIP], 
                 "z0"    : tree["SiTracks_Refitted_1.Z0"][atIP], 
                 "t"     : tree["SiTracks_Refitted_1.time"][atIP] ,
                 "chi2"  : tree["SiTracks_Refitted.chi2"], 
                 "ndf"   : tree["SiTracks_Refitted.ndf"], 
                 "dEdx"  : tree["SiTracks_Refitted.dEdx"], 
                 "rInner" : tree["SiTracks_Refitted.radiusOfInnermostHit"]},
                                   with_name="Momentum4D")

# %% [markdown]
# ## Now make some plots!

# %%
# a handy plotting function
def plot1DHistogram(data,bins,scale='linear',label=""):
    
    # handle data, there must be a smarter way to do this...
    if type(data[0])==np.int64 : data_flat=data
    elif type(data[0])==np.float32 : data_flat=data
    else: data_flat = ak.flatten(data)
    
    fig = plt.figure(figsize=(5,4))
    ax = fig.add_subplot(111)
    
    ax.hist(data_flat, bins=bins)
    
    # handle labels
    title  = "" if len(label.split(";")) < 1 else label.split(";")[0]  
    xlabel = "" if len(label.split(";")) < 2 else label.split(";")[1]  
    ylabel = "" if len(label.split(";")) < 3 else label.split(";")[2] 
    
    ax.set_title(title)
    ax.set_xlabel(xlabel, fontsize=15)
    ax.set_ylabel(ylabel, fontsize=15)
    plt.yscale(scale)
    plt.show()

# %%
# a handy plotting function
def plot2DHistogram(datax, datay, bins=100, norm="log", label=""):
    
    data_flatx = np.array(np.ravel(datax)).T
    data_flaty = np.array(np.ravel(datay)).T
    #print(len(data_flatx),data_flatx)
    #print(len(data_flaty),data_flaty)
    
    fig = plt.figure(figsize=(5,4))
    ax = fig.add_subplot(111)

    hh = ax.hist2d(data_flatx, data_flaty, bins=bins, norm=norm, cmap="plasma")
    
    title  = "" if len(label.split(";")) < 1 else label.split(";")[0]  
    xlabel = "" if len(label.split(";")) < 2 else label.split(";")[1]  
    ylabel = "" if len(label.split(";")) < 3 else label.split(";")[2]  
    zlabel = "" if len(label.split(";")) < 4 else label.split(";")[3] 
    
    ax.set_title(title)
    ax.set_xlabel(xlabel, fontsize=15)
    ax.set_ylabel(ylabel, fontsize=15)
    
    # colorbars are annoying
    cbar = fig.colorbar(hh[3])
    #cbar.ax.tick_params(labelsize=tick_font_size)
    cbar.set_label(zlabel, fontsize=15)

    plt.show()

# %% [markdown]
# ## Truth Muon Distributions

# %%
plot1DHistogram(truthMuons.pt     , bins=20  , label=";truth muon $p_{T}$ (GeV)")
plot1DHistogram(truthMuons.eta    , np.linspace(-3.5,3.5,20), label=";truth muon $\eta$")
plot1DHistogram(truthMuons.phi    , np.linspace(-3.5,3.5,20), label=";truth muon $\phi$")
plot1DHistogram(truthMuons.charge , np.linspace(-1.5,1.5,4) , label=";truth muon charge")

# %%
#plot muons
plot2DHistogram(muonHits.z, muonHits.y , bins=100, label="muon hits;z (mm);y (mm)")

# separate into barrel and endcap
barrel=abs(muonHits.z)<4000
endcapA=muonHits.z>4000
plot2DHistogram(muonHits.x[barrel], muonHits.y[barrel] , bins=100, label="muon barrel hits;x (mm);y (mm)")
plot2DHistogram(muonHits.x[endcapA], muonHits.y[endcapA] , bins=100, label="muon endcapA hits;x (mm);y (mm)")

# %% [markdown]
# ## Plot tracks without any selections

# %%
# basic kinematics
plot1DHistogram(ak.num(tracks) , bins=np.linspace(0,3000,200), scale='log', label=";$n_{Tracks}$")

plot1DHistogram(tracks.pt , bins=np.linspace(0,10,100), scale='log', label=";track $p_T$ (GeV)")
plot1DHistogram(tracks.pt , bins=np.linspace(0,500,100), scale='log', label=";track $p_T$ (GeV)")
plot1DHistogram(tracks.eta, bins=np.linspace(-3.5,3.5,100), label=";track $\eta$")
plot1DHistogram(tracks.phi, bins=np.linspace(-3.5,3.5,100), label=";track $\phi$")

# impact parameters, distance of closest approach
plot1DHistogram(tracks.d0, bins=np.linspace(-25,25,100), scale='log', label=";track $d{0}$ (mm)")
plot1DHistogram(tracks.z0, bins=np.linspace(-25,25,100), scale='log', label=";track $z{0}$ (mm)")

# quality variables
plot1DHistogram(tracks.chi2, bins=np.linspace(0,20,20), scale='log', label=";track $\chi^2$")
plot1DHistogram(tracks.ndf , bins=np.linspace(0,40,40), scale='log', label=";track $n_{dof}$")
plot1DHistogram(tracks.chi2/tracks.ndf, bins=np.linspace(0,10,200), label=";track $\chi^2/n_{dof}$")

# %%
# try and select high quality tracks
clean=(tracks.ndf>7)&(tracks.pt>1) # use ndf as a proxy for-nhits

plot1DHistogram(ak.num(tracks[clean]), bins=np.linspace(-0.5,10.5,12), label=";$cleaned n_{Tracks}$")

plot1DHistogram(tracks.eta[clean], bins=np.linspace(-3.5,3.5,20), label=";cleaned track $\eta$")
plot1DHistogram(tracks.pt[clean], bins=np.linspace(0,1000,100), scale='log', label=";cleaned track $p_{T}$ (GeV)")

plot1DHistogram(tracks.d0[clean], bins=np.linspace(-25,20,100), scale='log', label=";cleaned track $d_0$ (mm)")
plot1DHistogram(tracks.z0[clean], bins=np.linspace(-25,20,100), scale='log', label=";cleaned track $z_0$ (mm)")

# %% [markdown]
# #  Now try to match truth muons to tracks
#
# Match truth muons to the track closest in $\Delta R= \sqrt {\Delta\eta)^2 +(\Delta\phi)^2}$
#
# Compare 'truth matched' tracks to 'unmatched' tracks. Note down differences in pt, eta, phi, quality of fit, number of hits on track etc. How do these differences compare to the 'track cleaning' from before?
#
# Do the same for Muon Hits, what rate of muon hits are not matched to a collision particle?

# %%
cleanTracks=tracks[(tracks.ndf>5)&(tracks.pt>1)] # to start, leave cut on ndf a little loose

all_pairs = ak.cartesian([cleanTracks,truthMuons])

# %%
# Test that it did what we want
for i in range(0,10):
    print(i, all_pairs[i])
# Out:
# 0 [({pt: 1.09, theta: 1.55, ...}, {px: -1.67, ...}), ({...}, {...})]
# 1 [({pt: 1.03, theta: 2.29, ...}, {px: 67.7, ...})]
# 2 [({pt: 1.02, theta: 2.42, ...}, {px: 8.19, ...}), (...), ..., ({...}, {...})]
# 3 [({pt: 619, theta: 1.94, ...}, {px: -512, ...})]
# 4 [({pt: 365, theta: 1.78, ...}, {px: -329, ...}), ({...}, {...})]
# 5 [({pt: 65.1, theta: 0.512, ...}, {px: -43.6, ...}), ({...}, {...})]
# 6 [({pt: 32.6, theta: 0.673, ...}, {px: 7.04, ...})]
# 7 [({pt: 51.6, theta: 2.71, ...}, {px: -28.9, ...})]
# 8 [({pt: 1.06, theta: 2.49, ...}, {px: 276, ...}), ({...}, {...})]
# 9 [({pt: 273, theta: 0.367, ...}, {px: 80.8, ...})]

# %%
# Now unzip for computing angles
trks, mus = ak.unzip(all_pairs)

# Identify pair with the minimum dR
dRs = trks.deltaR(mus)
which = ak.argmin(abs(dRs), axis=1, keepdims=True) 

# also require dR < 0.1
dRcut = dRs[which]<0.1
matched = which[dRcut]

for i in range(0,10):
    print(i, dRs[i], which[i], matched[i], trks[matched][i].pt, mus[matched][i].pt)
# Out:
# 0 [2.91, 4.77e-05] [1] [1] [87.5] [87.7]
# 1 [1.73] [0] [] [] []
# 2 [2.51, 2.87, 3.12, 1.81, 0.000216] [4] [4] [10.1] [10.1]
# 3 [2.07e-05] [0] [0] [619] [610]
# 4 [0.000122, 1.83] [0] [0] [365] [366]
# 5 [5.59e-06, 0.823] [0] [0] [65.1] [66]
# 6 [0.000145] [0] [0] [32.6] [32.7]
# 7 [0.000112] [0] [0] [51.6] [51.5]
# 8 [3.32, 0.000672] [1] [1] [89.7] [383]
# 9 [8.14e-05] [0] [0] [273] [281]

# %%
# a handy plotting function
colors = []
def compare1DHistograms(datas,bins,scale='linear',label="",leg=[]):

    fig = plt.figure(figsize=(5,4))
    ax = fig.add_subplot(111)
    
    for i,data in enumerate(datas): 

        # handle data, there must be a smarter way to do this...
        if type(data[0])==np.int64   : data_flat=data
        elif type(data[0])==np.float32 : data_flat=data
        else : data_flat = ak.flatten(data, axis=None)
            
        ax.hist(data_flat, bins, alpha=0.5, label=leg[i] if len(leg)>i else "")
   
    # handle labels
    title  = "" if len(label.split(";")) < 1 else label.split(";")[0]  
    xlabel = "" if len(label.split(";")) < 2 else label.split(";")[1]  
    ylabel = "" if len(label.split(";")) < 3 else label.split(";")[2] 
    
    ax.set_title(title)
    ax.set_xlabel(xlabel, fontsize=15)
    ax.set_ylabel(ylabel, fontsize=15)
    plt.legend()
    plt.yscale(scale)
    plt.show()

# %%
# plot all dRs

arrays = [dRs,dRs[matched]]
legends= ["all $\Delta R$", "matched $\Delta R$"]

compare1DHistograms(arrays, bins=np.linspace(0,7,50), leg=legends, label=";$\Delta R(track, truth~muon)$")

# %% [markdown]
# # Follow up
#
# Investigate the following
# * Efficiency: What fraction of truth muons were reconstructed as 'clean tracks'?
# * Fake rate: What fraction of clean tracks were not matched to a truth muon?
# * How would loosening your clean track selection improve efficiency? improve your fake rate?
# * How close are the reconstructed tracks parameters to those of the truth muon? eg. pT, eta, phi, etc

# %%
# Steps towards efficiency
recodMuons = mus[matched]

arrays = [truthMuons.pt,recodMuons.pt]
legend = [ "All Truth Muons","Reco-Matched Truth Muons"]
compare1DHistograms(arrays, bins=np.linspace(0,1000,30), leg=legend, label=";truth muon $p_{T}$ (GeV)")

arrays = [truthMuons.eta,recodMuons.eta]
legend = [ "All Truth Muons","Reco-Matched Truth Muons"]
compare1DHistograms(arrays, bins=np.linspace(-3.5,3.5,30), leg=legend, label=";truth muon $\eta$")

# %%
# Steps towards fake rate
matchedTracks = trks[matched]

arrays = [cleanTracks.pt,matchedTracks.pt]
legend = [ "All Tracks","Truth-Matched Tracks"]
compare1DHistograms(arrays, bins=np.linspace(0,1000,30), leg=legend, scale='log',label=";track $p_{T}$ (GeV)")
compare1DHistograms(arrays, bins=np.linspace(0,20,40), leg=legend, label=";track $p_{T}$ (GeV)")

arrays = [cleanTracks.eta,matchedTracks.eta]
legend = [ "All Truth Muons","Reco-Matched Truth Muons"]
compare1DHistograms(arrays, bins=np.linspace(-3.5,3.5,30), leg=legend, label=";track $\eta$")

arrays = [cleanTracks.ndf,matchedTracks.ndf]
legend = [ "All Truth Muons","Reco-Matched Truth Muons"]
compare1DHistograms(arrays, bins=np.linspace(0,40,80), leg=legend, scale='log', label=";track $n_{df}$")
